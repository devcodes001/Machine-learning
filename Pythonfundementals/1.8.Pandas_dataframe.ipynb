# %% [markdown]
# <a href="https://colab.research.google.com/github/devcodes001/Machine-learning/blob/main/Pythonfundementals/1.8.Pandas_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DataFrame :
# it is a 2d stucture of data consisting of rows and columns,its one single column or row is series

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Creating DataFrame

# %%
#using list
student_data = [
    [100,80,10],
    [90,70,10],
    [17,13,12]
]

# %%
df = pd.DataFrame(student_data,columns = ['iq','marks','package'])
df
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70       10
# 2   17     13       12

# %%
#using dictionary
dic = {'name' : ['dev','veda','raj'],'maths':[12,13,15],'eng':[10,9,8],'mal':[76,65,34]}
df = pd.DataFrame(dic)
df.set_index('name')
# Out:
#       maths  eng  mal
# name
# dev      12   10   76
# veda     13    9   65
# raj      15    8   34

# %%
#using csv
df = pd.read_csv('/content/drive/MyDrive/datasets-session-17/batsman_runs_ipl.csv')
df
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %% [markdown]
# # Dataframe attributes & methods

# %%
#shape
df.shape
# Out:
# (605, 2)

# %%
#dtype
df.dtypes
# Out:
# batter         object
# batsman_run     int64
# dtype: object

# %%
#size
df.size
# Out:
# 1210

# %%
#itemsize
df.columns
# Out:
# Index(['batter', 'batsman_run'], dtype='object')

# %%
#values
df.values
# Out:
# array([['A Ashish Reddy', 280],
#        ['A Badoni', 161],
#        ['A Chandila', 4],
#        ...,
#        ['Younis Khan', 3],
#        ['Yuvraj Singh', 2754],
#        ['Z Khan', 117]], dtype=object)

# %%
#head()
df.head()
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25

# %%
#tail()
df.tail()
# Out:
#             batter  batsman_run
# 600     Yash Dayal            0
# 601  Yashpal Singh           47
# 602    Younis Khan            3
# 603   Yuvraj Singh         2754
# 604         Z Khan          117

# %%
#sample()
df.sample()
# Out:
#        batter  batsman_run
# 544  T Shamsi            2

# %%
#info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 605 entries, 0 to 604
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   batter       605 non-null    object
#  1   batsman_run  605 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 9.6+ KB

# %%
#isnull()
df.isnull().sum()
# Out:
# batter         0
# batsman_run    0
# dtype: int64

# %%
#rename
df.rename(columns = {'batter' : 'batsman'})
# Out:
#             batsman  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
#describe()
df.describe()
# Out:
#        batsman_run
# count   605.000000
# mean    464.428099
# std     985.272855
# min       0.000000
# 25%      15.000000
# 50%      73.000000
# 75%     326.000000
# max    6634.000000

# %%
#duplicated
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Math methods

# %%
#sum()
df['batsman_run'].sum()
# Out:
# 280979

# %%
#mean()
df['batsman_run'].mean()
# Out:
# 464.42809917355373

# %%
#var()
df['batsman_run'].var()
# Out:
# 970762.5995402551

# %% [markdown]
# ## Selecting columns from a dataframe

# %%
#df['column_name'] # ->this will return the corrrespoding column
df['batsman_run']
# Out:
# 0       280
# 1       161
# 2         4
# 3        53
# 4        25
#        ...
# 600       0
# 601      47
# 602       3
# 603    2754
# 604     117
# Name: batsman_run, Length: 605, dtype: int64

# %%
df[['batter','batsman_run']]
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %% [markdown]
# ## Selecting rowa from a dataframe
# - iloc - searches using index positions
# - loc - searches using index labels

# %%
df.iloc[5]
# Out:
# batter         A Dananjaya
# batsman_run              4
# Name: 5, dtype: object

# %%
df.iloc[:5]
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25

# %%
#facny indexing
df.iloc[[0,3,4]]
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 3        A Chopra           53
# 4     A Choudhary           25

# %%
#loc
df.loc[0]
# Out:
# batter         A Ashish Reddy
# batsman_run               280
# Name: 0, dtype: object

# %%
df.loc[[0,1,2]]
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4

# %% [markdown]
# ## Selecting both rows and columns

# %%
df.iloc[:,:1]
# Out:
#              batter
# 0    A Ashish Reddy
# 1          A Badoni
# 2        A Chandila
# 3          A Chopra
# 4       A Choudhary
# ..              ...
# 600      Yash Dayal
# 601   Yashpal Singh
# 602     Younis Khan
# 603    Yuvraj Singh
# 604          Z Khan
#
# [605 rows x 1 columns]

# %% [markdown]
# ## Filtering a DataFrame

# %%
df.head(2)
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161

# %%
df = pd.read_csv('/content/drive/MyDrive/datasets-session-17/ipl-matches.csv')

# %%
df.head(50)
# Out:
#          ID         City        Date Season  MatchNumber  \
# 0   1312200    Ahmedabad  2022-05-29   2022        Final
# 1   1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2   1312198      Kolkata  2022-05-25   2022   Eliminator
# 3   1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4   1304116       Mumbai  2022-05-22   2022           70
# 5   1304115       Mumbai  2022-05-21   2022           69
# 6   1304114       Mumbai  2022-05-20   2022           68
# 7   1304113       Mumbai  2022-05-19   2022           67
# 8   1304112  Navi Mumbai  2022-05-18   2022           66
# 9   1304111       Mumbai  2022-05-17   2022           65
# 10  1304110  Navi Mumbai  2022-05-16   2022           64
# 11  1304109       Mumbai  2022-05-15   2022           63
# 12  1304108       Mumbai  2022-05-15   2022           62
# 13  1304107         Pune  2022-05-14   2022           61
# 14  1304106       Mumbai  2022-05-13   2022           60
# ...

# %%
#find all the final winners
df[(df['MatchNumber'] == 'Final')]['WinningTeam']
# Out:
# 0             Gujarat Titans
# 74       Chennai Super Kings
# 134           Mumbai Indians
# 194           Mumbai Indians
# 254      Chennai Super Kings
# 314           Mumbai Indians
# 373      Sunrisers Hyderabad
# 433           Mumbai Indians
# 492    Kolkata Knight Riders
# 552           Mumbai Indians
# 628    Kolkata Knight Riders
# 702      Chennai Super Kings
# 775      Chennai Super Kings
# 835          Deccan Chargers
# 892         Rajasthan Royals
# Name: WinningTeam, dtype: object

# %%
df['WonBy'].unique()
# Out:
# array(['Wickets', 'Runs', 'SuperOver', 'NoResults'], dtype=object)

# %%
# how many super over finishes have occured
df[df['WonBy'] == 'SuperOver'].shape[0]
# Out:
# 14

# %%
# how many matches has csk won in kolkata
df[(df['City'] == 'Kolkata' ) &  (df['WinningTeam'] == 'Chennai Super Kings') ].shape[0]
# Out:
# 5

# %%
# toss winner is match winner in percentage
(df[df['TossWinner'] == df['WinningTeam']].shape[0] / df['TossWinner'].shape[0]) * 100
# Out:
# 51.473684210526315

# %%
# movies with rating higher than 8 and votes>10000
movies = pd.read_csv('/content/drive/MyDrive/datasets-session-17 (1)/movies.csv')

# %%
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
movies[(movies['imdb_rating']> 8.5) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 0

# %%
# Action movies with rating higher than 7.5
c1 = movies['genres'].str.contains('Action')
c2 = movies['imdb_rating'] > 7.5
movies[c1 & c2]
# Out:
#                             title_x    imdb_id  \
# 0          Uri: The Surgical Strike  tt8291224
# 41             Family of Thakurganj  tt8897986
# 84                        Mukkabaaz  tt7180544
# 106                           Raazi  tt7098658
# 110   Parmanu: The Story of Pokhran  tt6826438
# 112         Bhavesh Joshi Superhero  tt6129302
# 169                The Ghazi Attack  tt6299040
# 219                Raag Desh (film)  tt6080746
# 258                   Irudhi Suttru  tt5310090
# 280                       Laal Rang  tt5600714
# 297                     Udta Punjab  tt4434004
# 354                   Dangal (film)  tt5074352
# 362               Bajrangi Bhaijaan  tt3863552
# 365          Baby (2015 Hindi film)  tt3848892
# 393      Detective Byomkesh Bakshy!  tt3447364
# 449               Titli (2014 film)  tt3019620
# 536                   Haider (film)  tt3390572
# 589                    Vishwaroopam  tt2199711
# 625                     Madras Cafe  tt2855648
# ...

# %% [markdown]
# ## Adding new cols

# %%
movies['Country'] = 'India'
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
df['iq'].astype('float')
# Out:
# 0    100.0
# 1     90.0
# 2     17.0
# Name: iq, dtype: float64
